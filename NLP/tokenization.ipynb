# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in c:\users\laptop care\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\laptop care\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\laptop care\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\laptop care\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\laptop care\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ---------------------------------- ----- 1.3/1.5 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 2.9 MB/s  0:00:00
# Installing collected packages: nltk
# Successfully installed nltk-3.9.2
# WARNING: Error parsing dependencies of celery: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pytz (>dev)
#          ~^
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corpus="""Horse is a strong animal. 
It is as beautiful as it's capability.
"""

# %%
print(corpus)
# Out:
# Horse is a strong animal.
# It is as beautiful as it's capability.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Laptop
# [nltk_data]     Care\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Horse is a strong animal.
# It is as beautiful as it's capability.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Horse',
#  'is',
#  'a',
#  'strong',
#  'animal',
#  '.',
#  'It',
#  'is',
#  'as',
#  'beautiful',
#  'as',
#  'it',
#  "'s",
#  'capability',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Horse', 'is', 'a', 'strong', 'animal', '.']
# ['It', 'is', 'as', 'beautiful', 'as', 'it', "'s", 'capability', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Horse',
#  'is',
#  'a',
#  'strong',
#  'animal',
#  '.',
#  'It',
#  'is',
#  'as',
#  'beautiful',
#  'as',
#  'it',
#  "'",
#  's',
#  'capability',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Horse',
#  'is',
#  'a',
#  'strong',
#  'animal.',
#  'It',
#  'is',
#  'as',
#  'beautiful',
#  'as',
#  'it',
#  "'s",
#  'capability',
#  '.']
