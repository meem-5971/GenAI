# %%
## Q&A,chatbots,text summarization
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Laptop
# [nltk_data]     Care\AppData\Roaming\nltk_data...
# True

# %%
lemmatizer=WordNetLemmatizer()

# %% [markdown]
# The word "running" could be a verb or a noun, and its lemma will differ depending on the context.
# If tagged as a verb, the lemmatizer returns "run".
# If tagged as a noun (the default), it remains "running".

# %%
lemmatizer.lemmatize("going",pos='v')
# Out:
# 'go'

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
for word in words:
    print(word+"---->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eat
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->history
# finally---->finally
# finalized---->finalize

# %%
lemmatizer.lemmatize("goes",pos='v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize("fairly",pos='v'),lemmatizer.lemmatize("sportingly")
# Out:
# ('fairly', 'sportingly')
